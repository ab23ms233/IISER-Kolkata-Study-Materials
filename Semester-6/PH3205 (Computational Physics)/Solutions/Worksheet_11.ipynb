# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Question 1**

# %% [markdown]
# **Part (a)**

# %%
# Trial function
def w1(x, b, x0):
    norm_const = np.sqrt(b)/np.arctan(1/np.sqrt(b))
    return norm_const * 1/(b + (x-x0)**2)

# Function to integrate
def f(x): 
    if x>0:
        return x**3/(np.exp(x) - 1)
    else:
        return 0

# %% [markdown]
# Checking for values of b and $x_0$
#
# $f(x)$ peaks at $x = 1$, hence we choose $x_0 = 1$, so that the peak of $w(x)$ also occurs at $x = 1$.
#
# $b$ controls the spread of the distribution between $x \in [0, 1]$.
#
# The normalisation constant is obtained by $\int_0^1 w(x) \, dx = 1$

# %%
# Parameters
xi, xf = 0, 1
Nx = 100
xs = np.linspace(xi, xf, Nx)
fs = [f(x) for x in xs]

# Setting b and x0
b = 0.2
x0 = 1
ws = w1(xs, b, x0)

# Plotting
plt.plot(xs, fs, label = "f(x)")
plt.plot(xs, ws, label = "w(x)")
plt.plot(xs, fs/ws, label = "f/w")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# **Part (b)**

# %% [markdown]
# Defining functions

# %%
# Inverse function of y(x)
def get_x(y, b):
    theta = (y-1)*np.arctan(1/np.sqrt(b))
    return 1 + np.sqrt(b)*np.tan(theta)

# f/w
def g(x, b):
    return f(x)/w1(x, b, x0)

# Monte-Carlo integration of g(x)
def MC_eval_g(n, b):
    store = 0.0
    for i in range(n):
        y = np.random.rand()
        store += g(get_x(y, b), b)
    return store/n

# %% [markdown]
# Implementing importance sampling for different N

# %%
Ns = np.concatenate((np.asarray([1,2,5])*10, np.asarray([1,2,5])*100))
np.random.seed(20)
exact = 0.2248

for n in Ns:
    val = MC_eval_g(n, b)
    print("%5d  %0.7f  %0.5f" %(n, val, abs(val-exact)))
# Out:
#    10  0.2319801  0.00718
#    20  0.2346733  0.00987
#    50  0.2384166  0.01362
#   100  0.2349619  0.01016
#   200  0.2250824  0.00028
#   500  0.2201589  0.00464

# %% [markdown]
# ## **Question 2**

# %% [markdown]
# **Part (a)**

# %%
def w2(x):
    return 1/(1 + (x-1)**2)

xi, xf = -50, 50
N = 1000
xs = np.linspace(xi, xf, N)
ws = w2(xs)

plt.plot(xs, ws)
plt.title("Distribution of w(x)")
plt.xlabel("x")
plt.ylabel("w(x)")

plt.grid()
plt.show()

# %% [markdown]
# **Part (b)**

# %% [markdown]
# Implementing Metropolis algorithm

# %%
# Parameters
x0 = 0.5
N = int(1e6)
dx = 1.0

x = x0
store = np.zeros(N)     # for storing each step

# Implementing random walk N times using Metropolis algorithm
for n in range(N):
    store[n] = x
    tmp = x + dx*(np.random.rand()-dx/2)
    a = min(1, w2(tmp)/w2(x))
    
    # Accept step if a=1, else accept it with probability a
    if a == 1:
        x = tmp
    else:
        p = np.random.rand()
        if p<=a:
            x = tmp

# %% [markdown]
# Plotting

# %%
values, edges = np.histogram(store, 50)
# bin_width = edges[1] - edges[0]
midpoints = [(edges[i]+edges[i+1])/2 for i in range(len(edges)-1)]

# Normalisation
values = values/np.max(values)
ws = ws/np.max(ws)

# Plotting
plt.plot(midpoints, values, label = "Generated")
plt.plot(xs, ws, label = "Original")
plt.xlabel("x")
plt.ylabel("w(x)")
plt.xlim(-50, 50)
plt.title("Metropolis algorithm for the distribution w(x)")

plt.legend()
plt.grid()
plt.show()
