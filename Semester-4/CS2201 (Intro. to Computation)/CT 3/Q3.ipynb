# %%
import math
import numpy as np
import scipy.integrate as spi

# %%
def f(x):
    return math.sin(x) + x

# %% [markdown]
# RECTANGULAR METHOD

# %%
N = 1000
a, b = 0, 2
h = (b-a)/N
x = a
rect_area = 0

for i in range(N):
    rect_area += h*f(x)
    x += h

print("Retangular method area:", rect_area)
# Out:
# Retangular method area: 3.413237067071342

# %%
3-math.cos(2)
# Out:
# 3.4161468365471426

# %% [markdown]
# TRAPEZOIDAL METHOD

# %%
N = 1000
a, b = 0, 2
h = (b-a)/N
x = a+h
trap_area = 0

for i in range(1, N):
    trap_area += h*f(x)
    x += h

trap_area += h*(f(a)+f(b))/2

print("Trapezoidal method area:", trap_area)
# Out:
# Trapezoidal method area: 3.4161463644981676

# %% [markdown]
# SIMPSON'S RULE

# %%
N = 1000
a, b = 0, 2
h = (b-a)/(2*N)
x = a+h
simp_area = 0

for i in range(1, 2*N):
    if i%2 == 1:
        simp_area += 4*f(x)
    else:
        simp_area += 2*f(x)
    
    x += h

simp_area += f(a) + f(b)
simp_area = (h/3)*simp_area

print("Simpson rule area:", simp_area)
# Out:
# Simpson rule area: 3.416146836547099

# %% [markdown]
# ACTUAL AREA

# %%
actual_area = 3 - math.cos(2)
print("Actual Area:", actual_area)
# Out:
# Actual Area: 3.4161468365471426
#
# Error in Rectangular Method: 0.002909769475800683
# Error in Trapezoidal Method: 4.7204897501984533e-07
# Error in Simpson Rule: 4.3520742565306136e-14

# %% [markdown]
# SCIPY TRAPEZOIDAL METHOD

# %%
N = 1000
a, b = 0, 2

x_trap = np.linspace(a, b, N)
y_trap = np.empty(N)

for i in range(N):
    x = x_trap[i]
    y_trap[i] = f(x)

spi_trap_area = spi.trapz(y_trap, x_trap)
print("Scipy Trapezoidal area:", spi_trap_area)
# Out:
# Scipy Trapezoidal area: 3.416146363552649

# %% [markdown]
# SCIPY SIMPSON METHOD

# %%
N = 1000
a, b = 0, 2

x_simp = np.linspace(a, b, 2*N)
y_simp = np.empty(2*N)

for i in range(2*N):
    x = x_simp[i]
    y_simp[i] = f(x)
    
spi_simp_area = spi.simpson(y_simp, x_simp)
print("Scipy Simpson area:", spi_simp_area)
# Out:
# Scipy Simpson area: 3.416146836509176

# %% [markdown]
# ERRORS IN DIFFERENT AREAS

# %%
print("Error in Rectangular Method:", abs(actual_area - rect_area))
print("Error in Trapezoidal Method:", abs(actual_area - trap_area))
print("Error in Simpson Rule:", abs(actual_area - simp_area))
print()
print("Error in Scipy Trapezoidal Method:", abs(actual_area - spi_trap_area))
print("Error in Scipy Simpson Rule:", abs(actual_area - spi_simp_area))
# Out:
# Error in Rectangular Method: 0.002909769475800683
# Error in Trapezoidal Method: 4.7204897501984533e-07
# Error in Simpson Rule: 4.3520742565306136e-14
#
# Error in Scipy Trapezoidal Method: 4.729944937942321e-07
# Error in Scipy Simpson Rule: 3.7966518817711403e-11
